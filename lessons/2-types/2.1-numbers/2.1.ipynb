# %% [markdown]
# # Unit 03 - Integers, Decimals, and Arithmetic
# ### In-Class Exercises

# %% [markdown]
# ### Arithmetic Operations
# 1. In the below code block, experiment with the arithmetic operations by setting `left` and `right` to different values.
#    1. Try changing `left` to a floating point value, such as `1.1`
#    1. Try chancing `right` to a negative value, such as `-12`

# %%
left = 1
right = 2

# Addition
print(left + right)

# Subtraction
print(left - right)

# Multiplication
print(left * right)

# Division
print(left / right)

#Exponentiation
print(left ** right)

# %% [markdown]
# ## Limitations of Floating Point
#
# * First, make a guess to what the result will be, then run the code block.
#   * Is the result what you expected? Why or why not?

# %%
print(1.0000000000000001 + 1.0000000000000001)
# Out:
# 2.0

# %% [markdown]
# ### Machine Epsilon
# * Smallest safely representable floating point number

# %%
import sys

machine_epsilon_sys = sys.float_info.epsilon
print("Machine epsilon {:.16f}: ".format(machine_epsilon_sys))
# Out:
# Machine epsilon 0.0000000000000002:

# %% [markdown]
# ## Practice and Review
# Write a program that prints out the answers to these questions:
# * 20 Plus 3
# * 30 Minus 5
# * 10 Times 4
# * 9 Divided by 3
# * 3 to the 4th Power
