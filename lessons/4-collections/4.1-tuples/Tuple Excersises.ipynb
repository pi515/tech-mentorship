# %%
# I want to order one french fry, 2 hot dogs, one soda
# Make a tuple that represents this order

myOrder = ()
print(myOrder)

# %%
# Oh no! I need to change my order! Can I do this, or do I need to make a new order?
# Update `myOrder` to change your order from two hot dogs to one hot dog, and one hamburger

print(myOrder)

# %%
# What's the second thing in my order?

print(myOrder)

# %%
# I want to split my order into two checks
# Ethan is getting the hotdog and fries.
# Sathya is getting the hamburger and soda.
# Make two new tuples from the original that represent the orders

print(ethansOrder)
print(sathyasOrder)
