# %% [markdown]
# # Exercise 1 - Creating a Set
#
# Create a set in python which contains the numbers: 7, 15, 43, 72
#
# Then print out the list

# %%
# Code for exercise 1 goes here

# %% [markdown]
# # Exercise 2 - Adding to a Set

# %%
# Code for exercise 2 goes here

# 1. Create an empty set in python. Completed for you
numbers = set()

# 2. Add the numbers 67 & 42 to the set.
#    Do not redefine the variables with "numbers ="

# 3. Print the set

# 4. Add the number 67 to the set again

# 5. Print the set again

# %% [markdown]
# # Exercise 3 - Removing from a Set

# %%
# Code for exercise 3 goes here

# 1. Create a set with the two strings "six” and “seven” in it

# 2. Remove “seven” from the set

# 3. Print the set

###################################################
# PLEASE RUN YOUR CODE BEFORE PROCEEDING TO THE NEXT STEP!
###################################################

# 4. Remove "seven" from the set again. What did you observe?

# %% [markdown]
# # Challenge Activity

# %%
# Our food truck menu should be a _set_ of available foods and drinks

# FIXME
menu == ['Pizza', "Hot Dog", 'PB&J', "Salad', 'Water', Soda];

print(menu)
print(type(menu))

# Did the last print say the type is a set?

# %%
# The food truck ran out of Hot Dogs but found some Burgers in the freezer!
# Please update the menu

# Do not change this line to redefine the menu variable!
menu = {'Pizza', 'Hot Dog', 'PB&J', 'Salad', 'Water', 'Soda'}

# Instead, use the methods we learned above to modify the menu
# Example: menu.methodName()

print(menu)

# %%
menu = {'Pizza', 'Hot Dog', 'PB&J', 'Salad', 'Water', 'Soda'}

# Create your order for the food truck and see if your order is available
# Hint: Does the menu contain your order?
myOrder = ""
print('Order Available: ')

# Make an order that isn't available
myOrder = ""
print('Order not Available: ')

# %%
# The food truck has separate menus for drinks and food

drinks = {'Water', 'Soda'}
foods = {'Pizza', 'Hot Dog', 'PB&J', 'Salad'}

print('Combined menu: ')

# %%
# A rival food truck approaches! Find out how the menus compare!

ourMenu = {'Pizza', 'Hot Dog', 'PB&J', 'Salad', 'Water', 'Soda'}
rivalMenu = {'Pasta', 'Pizza', 'Salad', 'Water', 'Soda'}

# 1. Find if the menu is different
# isDifferent =
print('Is Different?: ')

# 2. Find the unique items on our menu
# ourUniqueItems =
print('Our Unique: ')

# 3. Find the unique items on the rival menu
# rivalUniqueItems =
print('Rival Unique: ')

# 4. Find all differences from both menus
print('All differences: ')

# 5. Find common items between the menus
# commonItems =
print('Common items: ')

# 6. We want our food truck to be unique!!
# Make a new menu with only the uniqe items from both menus.
# Make sure to save the old menu in case our rival leaves! (Has many answers)

print('Old menu: ')
print('New menu: ')
